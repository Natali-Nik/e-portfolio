# %%
# calculate the Pearson's correlation between two variables
from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr
# seed random number generator
seed(1)

# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)

# calculate covariance matrix
covariance = cov(data1, data2)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)

# plot
plt.scatter(data1, data2)
plt.show()

# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358
# Covariance: 389.755
# Pearsons correlation: 0.888

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()  # Display the first five rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35a52546ae2b> in <cell line: 1>()
# ----> 1 df.head()  # Display the first five rows
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is in 'data1' and 'data2' from the previous code,
# Create a pandas DataFrame
df = pd.DataFrame({'data1': data1, 'data2': data2})

df.head()  # Display the first five rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a90bd0aabbc3> in <cell line: 8>()
#       6 # Assuming your data is in 'data1' and 'data2' from the previous code,
#       7 # Create a pandas DataFrame
# ----> 8 df = pd.DataFrame({'data1': data1, 'data2': data2})
#       9
#      10 df.head()  # Display the first five rows
#
# NameError: name 'data1' is not defined

# %%
# prompt: an explorartory analysis

from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seed random number generator
seed(1)

# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)

# calculate covariance matrix
covariance = cov(data1, data2)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)

# Create a pandas DataFrame
df = pd.DataFrame({'data1': data1, 'data2': data2})

# Display basic statistics
print(df.describe())

# Histograms
df.hist(figsize=(10, 5))
plt.show()

# Boxplots
df.plot(kind='box', subplots=True, layout=(1,2), sharex=False, sharey=False, figsize=(10,5))
plt.show()

# Scatter plot with regression line
sns.regplot(x='data1', y='data2', data=df)
plt.show()

# Correlation matrix heatmap
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()


#Pairplot
sns.pairplot(df)
plt.show()

#Summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
#              data1        data2
# count  1000.000000  1000.000000
# mean    100.776250   151.049504
# std      19.629900    22.369177
# min      38.924712    80.022829
# 25%      87.996791   136.727420
# 50%     100.825852   150.717648
# 75%     114.079977   165.576681
# max     179.172054   232.119130
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358
# Covariance: 389.755
# Pearsons correlation: 0.888

# %% [markdown]
# what is the trend based on these results

# %%
adjust the data so that Data 1 has a similar count like data2
# Out:
#   File "<ipython-input-9-e6c90c839c29>", line 1
#     adjust the data so that Data 1 has a similar count like data2
#            ^
# SyntaxError: invalid syntax

# %%
# prompt: adjust the data so that Data 1 has a similar count like data2

import pandas as pd
import numpy as np

# ... (Your existing code) ...

# Assuming 'data1' and 'data2' are your NumPy arrays

# Method 1: Random sampling with replacement
# This will create a new 'data1' with the same size as 'data2' by sampling with replacement
n_samples = len(data2)  # or any desired size
data1_adjusted = np.random.choice(data1, size=n_samples, replace=True)

# Method 2:  Resampling to match the distribution but with the same number of data points
# This method adjusts the data distribution of data1 to match the mean and std of data2

# Calculate the mean and standard deviation of data2
mean_data2 = np.mean(data2)
std_data2 = np.std(data2)

# Standardize data1
data1_standardized = (data1 - np.mean(data1)) / np.std(data1)

# Transform data1 to match the mean and standard deviation of data2
data1_adjusted = (data1_standardized * std_data2) + mean_data2

# Now create the DataFrame with the adjusted data
df_adjusted = pd.DataFrame({'data1': data1_adjusted, 'data2': data2})

# Display basic statistics of the adjusted DataFrame
print(df_adjusted.describe())

# ... (rest of your code with df_adjusted instead of df) ...
# Out:
#              data1        data2
# count  1000.000000  1000.000000
# mean    151.049504   151.049504
# std      22.369177    22.369177
# min      80.566824    80.022829
# 25%     136.486722   136.727420
# 50%     151.106028   150.717648
# 75%     166.209715   165.576681
# max     240.385139   232.119130

# %%
# prompt: visualize these new results

# ... (Your existing code) ...

# Assuming 'data1' and 'data2' are your NumPy arrays

# Method 1: Random sampling with replacement
# This will create a new 'data1' with the same size as 'data2' by sampling with replacement
n_samples = len(data2)  # or any desired size
data1_adjusted = np.random.choice(data1, size=n_samples, replace=True)

# Method 2:  Resampling to match the distribution but with the same number of data points
# This method adjusts the data distribution of data1 to match the mean and std of data2

# Calculate the mean and standard deviation of data2
mean_data2 = np.mean(data2)
std_data2 = np.std(data2)

# Standardize data1
data1_standardized = (data1 - np.mean(data1)) / np.std(data1)

# Transform data1 to match the mean and standard deviation of data2
data1_adjusted = (data1_standardized * std_data2) + mean_data2

# Now create the DataFrame with the adjusted data
df_adjusted = pd.DataFrame({'data1': data1_adjusted, 'data2': data2})

# Display basic statistics of the adjusted DataFrame
print(df_adjusted.describe())

# Histograms of adjusted data
df_adjusted.hist(figsize=(10, 5))
plt.show()

# Boxplots of adjusted data
df_adjusted.plot(kind='box', subplots=True, layout=(1,2), sharex=False, sharey=False, figsize=(10,5))
plt.show()

# Scatter plot with regression line of adjusted data
sns.regplot(x='data1', y='data2', data=df_adjusted)
plt.show()

# Correlation matrix heatmap of adjusted data
corr_matrix_adjusted = df_adjusted.corr()
sns.heatmap(corr_matrix_adjusted, annot=True, cmap='coolwarm')
plt.show()

#Pairplot of adjusted data
sns.pairplot(df_adjusted)
plt.show()

# Calculate Pearson's correlation for adjusted data
corr_adjusted, _ = pearsonr(data1_adjusted, data2)
print('Adjusted Pearsons correlation: %.3f' % corr_adjusted)
# Out:
#              data1        data2
# count  1000.000000  1000.000000
# mean    151.049504   151.049504
# std      22.369177    22.369177
# min      80.566824    80.022829
# 25%     136.486722   136.727420
# 50%     151.106028   150.717648
# 75%     166.209715   165.576681
# max     240.385139   232.119130
# Adjusted Pearsons correlation: 0.888

# %%
# prompt: change variables as needed to observe how the change in data points impacts correlation and regression.

from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seed random number generator
seed(1)

# prepare data -  making data2 dependent on data1, but with some noise
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)

#User can change the number of data points here
n_data_points = 900 #@param {type:"slider", min:100, max:2000, step:100}


#Adjust data1 to have similar count as data2 (using random sampling)
data1 = np.random.choice(data1, size=n_data_points, replace=False)

#adjust data2 to have similar count to data1
data2 = np.random.choice(data2, size=n_data_points, replace=False)

# Calculate covariance matrix
covariance = cov(data1, data2)

# Calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)


# Create a pandas DataFrame
df_adjusted = pd.DataFrame({'data1': data1, 'data2': data2})

# Display basic statistics of the adjusted DataFrame
print(df_adjusted.describe())


# Histograms of adjusted data
df_adjusted.hist(figsize=(10, 5))
plt.show()

# Boxplots of adjusted data
df_adjusted.plot(kind='box', subplots=True, layout=(1,2), sharex=False, sharey=False, figsize=(10,5))
plt.show()

# Scatter plot with regression line of adjusted data
sns.regplot(x='data1', y='data2', data=df_adjusted)
plt.show()

# Correlation matrix heatmap of adjusted data
corr_matrix_adjusted = df_adjusted.corr()
sns.heatmap(corr_matrix_adjusted, annot=True, cmap='coolwarm')
plt.show()

#Pairplot of adjusted data
sns.pairplot(df_adjusted)
plt.show()

# Calculate Pearson's correlation for adjusted data
corr_adjusted, _ = pearsonr(data1, data2)
print('Adjusted Pearsons correlation: %.3f' % corr_adjusted)

#Summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
#             data1       data2
# count  900.000000  900.000000
# mean   100.904941  150.754601
# std     19.517458   22.211210
# min     44.138300   80.022829
# 25%     88.130628  136.609551
# 50%    100.872659  150.430354
# 75%    113.890654  165.155610
# max    179.172054  232.119130
# Adjusted Pearsons correlation: -0.014
# data1: mean=100.905 stdv=19.507
# data2: mean=150.755 stdv=22.199
# Covariance: -6.286
# Pearsons correlation: -0.014
