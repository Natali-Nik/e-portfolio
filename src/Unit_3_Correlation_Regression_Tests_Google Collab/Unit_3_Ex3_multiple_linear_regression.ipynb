# %%
import pandas
from sklearn import linear_model

df = pandas.read_csv("cars.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = regr.predict([[2300, 1300]])

print(predictedCO2)
# Out:
# [107.2087328]

# %% [markdown]
# # Coefficient

# %% [markdown]
# The coefficient is a factor that describes the relationship with an unknown variable.
# In this case, we can ask for the coefficient value of weight against CO2, and for volume against CO2. The answer(s) we get tells us what would happen if we increase, or decrease, one of the independent values.

# %%
print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %% [markdown]
# The result array represents the coefficient values of weight and volume.
#
# Weight: 0.00755095
# Volume: 0.00780526
#
# These values tell us that if the weight increase by 1kg, the CO2 emission increases by 0.00755095g.
#
# And if the engine size (Volume) increases by 1 cm3, the CO2 emission increases by 0.00780526 g.
#
# I think that is a fair guess, but let test it!
#
# We have already predicted that if a car with a 1300cm3 engine weighs 2300kg, the CO2 emission will be approximately 107g.
#
# What if we increase the weight with 1000kg (from 2300 to 3300) what will be the CO2 emission?
#
# Ans: 107.2087328 + (1000 * 0.00755095) = 114.75968

# %%
predictedCO2 = regr.predict([[3300, 1300]])

print(predictedCO2)
# Out:
# [114.75968007]

# %%
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import numpy as np

# %%
data = {'x': df[['Weight', 'Volume']].values,
        'y': df['CO2'].values}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3fca31bb5a3b> in <cell line: 1>()
# ----> 1 data = {'x': df[['Weight', 'Volume']].values,
#       2         'y': df['CO2'].values}
#       3 df = pd.DataFrame(data)
#
# NameError: name 'df' is not defined

# %%
df = pandas.read_csv("cars.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ce1f2c51c849> in <cell line: 1>()
# ----> 1 df = pandas.read_csv("cars.csv")
#
# NameError: name 'pandas' is not defined

# %%
# prompt: how to extract sample data from cars.csv file

# Print some of the first rows
print(df.head())

# Print some of the last rows
print(df.tail())

# Print a sample of 5 random rows
print(df.sample(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-85433218a12b> in <cell line: 4>()
#       2
#       3 # Print some of the first rows
# ----> 4 print(df.head())
#       5
#       6 # Print some of the last rows
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Uploaded cars.csv file locally
df = pd.read_csv('Unit03 cars.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-f04d2967e2e5> in <cell line: 4>()
#       2
#       3 # Uploaded cars.csv file locally
# ----> 4 df = pd.read_csv('Unit03 cars.csv')
#       5 print(df.head())
#
# ...

# %%
 # Uploaded cars.csv file locally
----> 4 df = pd.read_csv('/Desktop/EssexPG/Module 3 PPTs and Content/Unit03 cars.csv')
      5 print(df.head())
# Out:
#   File "<ipython-input-8-694101c60f8a>", line 2
#     ----> 4 df = pd.read_csv('/Desktop/EssexPG/Module 3 PPTs and Content/Unit03 cars.csv')
#        ^
# SyntaxError: invalid syntax

# %%
from google.colab import files
uploaded = files.upload()  # This will prompt you to upload the file

# Uploading file "Unit03 cars.csv"
df = pd.read_csv('Unit03 cars.csv')
# Out:
#      <input type="file" id="files-3741cb27-8662-4748-8aa1-781fe37beef6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3741cb27-8662-4748-8aa1-781fe37beef6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas
from sklearn import linear_model

df = pandas.read_csv("cars.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-eae2f64b3bfe> in <cell line: 4>()
#       2 from sklearn import linear_model
#       3
# ----> 4 df = pandas.read_csv("cars.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Unit03 cars.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('car name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['weight'].plot(kind='hist', bins=20, title='weight')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
# ...

# %%
from matplotlib import pyplot as plt
_df_26['weight'].plot(kind='hist', bins=20, title='weight')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_35['weight'].plot(kind='line', figsize=(8, 4), title='weight')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_25['displacement'].plot(kind='hist', bins=20, title='displacement')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"{col} unique values:\n", df[col].value_counts(), "\n")
# Out:
# horsepower unique values:
#  horsepower
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: count, Length: 94, dtype: int64
#
# car name unique values:
#  car name
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64

# %%
for col in df.select_dtypes(include=[np.number]).columns:
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-d41c670d8d84> in <cell line: 1>()
# ----> 1 correlation_matrix = df.corr()
#       2 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#       3 plt.title('Correlation Matrix')
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
sns.scatterplot(data=df, x='Column1', y='Column2')  # Replace 'Column1' and 'Column2' with actual column names
plt.title('Scatter Plot between Column1 and Column2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-88d6b22826df> in <cell line: 1>()
# ----> 1 sns.scatterplot(data=df, x='Column1', y='Column2')  # Replace 'Column1' and 'Column2' with actual column names
#       2 plt.title('Scatter Plot between Column1 and Column2')
#       3 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# ...

# %%
sns.scatterplot(data=df, x='car name', y='weight')
plt.title('Scatter Plot between car name and weight')
plt.show()

# %%
# prompt: fix that visual since you cannot see the car names

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (Your existing code)

# Assuming 'car name' is the column with car names
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
sns.scatterplot(data=df, x='car name', y='weight')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.title('Scatter Plot between car name and weight')
plt.show()

# %%
# prompt: import file for further analysis

import pandas as pd
import numpy as np
from google.colab import files
import seaborn as sns
from matplotlib import pyplot as plt

uploaded = files.upload()
df = pd.read_csv('cars.csv')

# Now you can perform further analysis on the dataframe 'df'
# ... (your analysis code goes here)

# Example: Display basic statistics
print(df.describe())

# Example: Visualize weight distribution
_df_3 = df.copy()  # Create a copy to avoid modifying the original DataFrame
_df_3['weight'].plot(kind='hist', bins=20, title='weight')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# Example: Check for missing values
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-282f63a02c22> in <cell line: 9>()
#       7 # Assuming 'df' is your DataFrame and 'car name' and 'weight' are your columns
#       8 # If your data is in a different file, replace 'cars.csv' accordingly
# ----> 9 df = pd.read_csv('cars.csv')
#      10
#      11 # Group by car name and get the mean weight
#
# ...

# %%
# prompt: import the cars.csv file

import pandas as pd

# Assuming the file 'cars.csv' is already in your Colab environment
# If not, upload it first using the following code:
# from google.colab import files
# uploaded = files.upload()

df = pd.read_csv('Unit03 cars.csv')

# Now you can work with the dataframe 'df'
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-43c291b9c16b> in <cell line: 10>()
#       8 # uploaded = files.upload()
#       9
# ---> 10 df = pd.read_csv('Unit03 cars.csv')
#      11
#      12 # Now you can work with the dataframe 'df'
#
# ...

# %%
# prompt: import unit03 cars.csv file

import pandas as pd
from google.colab import files

uploaded = files.upload()
df = pd.read_csv('Unit03 cars.csv')
print(df.head())
# Out:
#      <input type="file" id="files-c34c9b58-3026-4b25-bb5f-a7f31a1156e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c34c9b58-3026-4b25-bb5f-a7f31a1156e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: show just the car names that are most common with the heighest weight as a scatterplot

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'cars.csv' is uploaded
# If not, upload it using files.upload() as shown in previous responses

df = pd.read_csv('Unit03 cars.csv')

# Group by car name and get the most common ones (top 10 for example)
top_cars = df.groupby('car name')['weight'].mean().sort_values(ascending=False).head(10)

# Create a new DataFrame with only the top cars
top_car_df = df[df['car name'].isin(top_cars.index)]

plt.figure(figsize=(12, 6))
sns.scatterplot(data=top_car_df, x='car name', y='weight')
plt.xticks(rotation=90)
plt.title('Scatter Plot of Most Common Cars with Highest Weight')
plt.show()

# %%
# prompt: analyze imbalances in the data

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'Unit03 cars.csv' is uploaded
# If not, upload it using files.upload() as shown in previous responses

df = pd.read_csv('Unit03 cars.csv')

# Analyze imbalances using various methods:

# 1. Summary Statistics:
print(df.describe())  # Provides basic statistics for numerical columns

# 2. Missing Value Analysis
print(df.isnull().sum())  # Check for missing values in each column

# 3. Distribution Plots:
for col in df.select_dtypes(include=['number']): #creates distribution plots for numerical data
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()


# 4. Correlation Analysis:
correlation_matrix = df.corr() #creates a correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()


# 5.  Outlier Detection (example using boxplots)
for col in df.select_dtypes(include=['number']): #creates boxplots to detect outliers in numerical data
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()


# 6. Imbalance in Categorical Features:
for col in df.select_dtypes(include=['object']): #creates bar plots to visualize imbalance in categorical data
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Value Counts of {col}')
    plt.show()


# 7.  Scatter Plots for Relationships (example):
# Replace 'weight' and 'Volume' with relevant columns
sns.scatterplot(data=df, x='weight', y='Volume')
plt.title('Scatter Plot of Weight vs Volume')
plt.show()

# Further analysis based on the specific imbalances you find
# (e.g., handling outliers, feature scaling, etc)
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
# mpg             0
# cylinders       0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'cars.csv' is already uploaded
# If not, upload it using:
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv('cars.csv')

df = pd.read_csv('Unit03 cars.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'cars.csv' is already uploaded
# If not, upload it using:
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv('cars.csv')

df = pd.read_csv('Unit03 cars.csv')
# 3. Violin Plot: Similar to a box plot, but also shows the distribution density.
plt.figure(figsize=(12, 6))
sns.violinplot(x='car name', y='CO2', data=df)
plt.xticks(rotation=90)
plt.title('Violin Plot of CO2 Emissions by Car Name')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fd828711ed71> in <cell line: 14>()
#      12 # 3. Violin Plot: Similar to a box plot, but also shows the distribution density.
#      13 plt.figure(figsize=(12, 6))
# ---> 14 sns.violinplot(x='car name', y='CO2', data=df)
#      15 plt.xticks(rotation=90)
#      16 plt.title('Violin Plot of CO2 Emissions by Car Name')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1723 ):
#    1724
# -> 1725     p = _CategoricalPlotter(
#    1726         data=data,
# ...

# %%
# prompt: change variables as needed to observe how the change in data points

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# Upload the 'cars.csv' file if it's not already in your Colab environment
uploaded = files.upload()
df = pd.read_csv('Unit03 cars.csv')  # Or 'cars.csv' if that's the name


# Now you can easily change the independent variables (features) and dependent variable (target)
# to see the impact on the linear regression model.

# Example 1:  Use 'Weight' and 'Volume' to predict 'CO2' (as in the original code)
X = df[['Weight', 'Volume']]
y = df['CO2']

# Example 2: Use 'Weight' and 'Displacement' to predict 'CO2'
# X = df[['Weight', 'Displacement']]  # Changed 'Volume' to 'Displacement'
# y = df['CO2']

# Example 3: Use only 'Weight' to predict 'CO2'
# X = df[['Weight']]
# y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

# Make predictions
# Change input values as needed
predictedCO2 = regr.predict([[2300, 1300]])  # Example with weight 2300, volume 1300
print(predictedCO2)

# Examine coefficients
print(regr.coef_)

# Visualizations
# Adjust features as per your variable changes in the model (X,y)
sns.scatterplot(data=df, x='Weight', y='CO2')
plt.title('Scatter Plot between Weight and CO2')
plt.show()

sns.regplot(x='Weight', y='CO2', data=df) # Use the regplot to visualize regression line along with scatter plot.
plt.show()

# Other visualizations using df
# ... (your existing visualization code can go here)

# 5.  Categorical Plots (if you have categorical data beyond car name):
#  e.g., if you had a 'fuel type' column:
# sns.countplot(x='fuel type', data=df)
# plt.title('Count of Cars by Fuel Type')
# plt.show()

# 6.  Heatmap of correlations between numerical features
plt.figure(figsize=(8, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()
# Out:
#      <input type="file" id="files-a99c9ce0-9637-4f36-878c-2782885da9fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a99c9ce0-9637-4f36-878c-2782885da9fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 3. Violin Plot: Similar to a box plot, but also shows the distribution density.
plt.figure(figsize=(12, 6))
sns.violinplot(x='car name', y='CO2', data=df)
plt.xticks(rotation=90)
plt.title('Violin Plot of CO2 Emissions by Car Name')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4b8aa2b5f6fc> in <cell line: 3>()
#       1 # 3. Violin Plot: Similar to a box plot, but also shows the distribution density.
#       2 plt.figure(figsize=(12, 6))
# ----> 3 sns.violinplot(x='car name', y='CO2', data=df)
#       4 plt.xticks(rotation=90)
#       5 plt.title('Violin Plot of CO2 Emissions by Car Name')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1723 ):
#    1724
# -> 1725     p = _CategoricalPlotter(
#    1726         data=data,
# ...
